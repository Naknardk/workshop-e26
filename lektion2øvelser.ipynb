# %%
navn = "vjola"
alder = 23
by = "aalborg"

print(f"Jeg hedder {navn}, jeg er {alder} år gammel, og jeg bor i {by}.") #f for format, så ved den at den skal udfylde det der står i tuborgklapperne
# Out:
# Jeg hedder vjola, jeg er 23 år gammel, og jeg bor i aalborg.

# %%
pris = 249
antal = 3
total = pris * antal
print(total)
print(type(pris))
print(type(navn))
# Out:
# 747
# <class 'int'>
# <class 'str'>

# %%
#øvelse 2 
saetning = "udvikling af IT"
By = "Øresund"

print(len(saetning))

print(saetning.upper())
print(saetning.lower())

print(saetning[0:9])

print(saetning.replace("IT", "informationsteknologi"))

print(saetning.split())
ord = ['udvikling', 'af', 'IT']
print(len(ord))

print(len(By), "tegn")

print(f"{len(By.encode())} bytes")
# Out:
# 15
# UDVIKLING AF IT
# udvikling af it
# udvikling
# udvikling af informationsteknologi
# ['udvikling', 'af', 'IT']
# 3
# 7 tegn
# 8 bytes

# %%
print(17+5)
print(17-5)
print(17*5)
print(17/5)
print(17//5)
print(17%5)
print(17**2)
# Out:
# 22
# 12
# 85
# 3.4
# 3
# 2
# 289

# %%
print(round(3.14159, 2))
print(int(3.9))
print(float(3))
# Out:
# 3.14
# 3
# 3.0

# %%
fødselsår = input("hvornår er du født")


Alder = 2026-int(fødselsår)

print(Alder)
# Out:
# 23

# %%
INDKOMSTGRAENSE = 300000
TILSKUD_PR_BARN = 1200
HUSLEJEANDEL = 0.35


INDKOMST = 240000 
BOERN = 2
HUSLEJE = 6500

IF
